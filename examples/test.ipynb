# %%
import jax.numpy as jnp
import jax

jax.config.update("jax_enable_x64", True)

# %%
neg_inv_sqrt_eps = -1.0 / jnp.sqrt(jnp.finfo(jnp.float64.dtype).eps)

# %%
neg_inv_sqrt_eps
# Out:
# Array(-6.7108864e+07, dtype=float32)

# %%
x = jnp.array(18.9, dtype=jnp.float64)
jnp.exp(x**2)
# Out:
# Array(1.36248547e+155, dtype=float64)

# %%
threshold = jnp.sqrt(0.5 * jnp.log(jnp.finfo(jnp.float64).max))

# %%
threshold
# Out:
# Array(18.83856036, dtype=float64)
